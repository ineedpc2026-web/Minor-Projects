# %% [markdown]
# <a href="https://colab.research.google.com/github/ineedpc2026-web/Minor-Projects/blob/main/Q3_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # S01 - Practice 3: Your First Programs

# %% [markdown]
# **Applied AI & Analytics Lab** · Session 1 · Practice notebook 3 of 3
#
# **Time:** about 25 minutes.
#
# The first two notebooks drilled the pieces. This one puts them together.
#
# By the end you will have:
# - proved your setup works, from the terminal and from a notebook
# - written three small programs from scratch
# - got the **first 3 logic drills of Minor Project 1** ready to commit to GitHub
#
# You only know types, operators and strings so far. That is enough. Every drill here
# is solvable with what you learned today - no loops, no `if`, no libraries.
#
# ---

# %% [markdown]
# ## Part A - Setup check
#
# ### Exercise 1 - Where am I?  ·  *easy*
#
# Run the cell. A line starting with `!` goes to the terminal instead of to Python.
# You are looking at the terminal from a safe place.

# %%
# !pwd
# !python --version
# Out:
# /content
# Python 3.12.13

# %% [markdown]
# ### Exercise 2 - Write and run a script  ·  *easy*
#
# `%%writefile` saves a cell to a file instead of running it.
# Write a script that prints your own name, then run it from the terminal.

# %%
# %%writefile my_first.py
# YOUR CODE HERE
name = "Harish Salve"
print(f"Hello, {name}. Day 1 of 32")
# It should print: Hello, <your name>. Day 1 of 32.
# Out:
# Overwriting my_first.py

# %% [markdown]
# Now run it the way you would from a real terminal.

# %%
# !python my_first.py
# Out:
# Hello, Harish Salve. Day 1 of 32

# %% [markdown]
# ### Exercise 3 - Notebook memory  ·  *easy*
#
# Notebooks remember what you ran, in the order you ran it.
# This is powerful and it is also the biggest source of confusion for beginners.
#
# Run these two cells in order, then run the first one again with a different number
# and see what happens.

# %%
x = 10

# %% [markdown]
# Run this one.

# %%
print(x * 2)     # Expect: 20
# Out:
# 20

# %% [markdown]
# ## Part B - Reading code
#
# ### Exercise 4 - Predict the output  ·  *medium*
#
# **Before running**, write your answer in the comment. Then run and check.
# Being wrong here is free. Being wrong in an interview is not.

# %%
# My prediction: 5
x = 5
y = x
x = 10
print(y)
# Out:
# 5

# %% [markdown]
# ### Exercise 5 - Predict the output  ·  *medium*

# %%
# My prediction: __1010__
print("10" + "10")

# My prediction: __20__
print(int("10") + int("10"))
# Out:
# 1010
# 20

# %% [markdown]
# ### Exercise 6 - Predict the output  ·  *medium*

# %%
# My prediction: __Anals__
s = "Analytics"
print(s[0:4] + s[-1])
# Out:
# Anals

# %% [markdown]
# ## Part C - Minor Project 1 - the first three drills
#
# These three go in your GitHub repository. Write each one as a **separate `.py` file**,
# not just a notebook cell. Recruiters read repositories, not notebooks.
#
# Rules for MP1:
# - No libraries. Nothing imported.
# - Clear variable names.
# - One comment per program saying what it does.
#
# ---
#
# ### Drill 1 - Temperature converter  ·  *medium*
#
# Convert 98.6 degrees Fahrenheit to Celsius. Formula: `C = (F - 32) * 5/9`.
# Print the answer rounded to 1 decimal place.

# %%
# %%writefile drill_01_temperature.py
# Drill 1: converts a temperature from Fahrenheit to Celsius.

# YOUR CODE HERE
F = 98.6
C =  (F - 32) * 5/9
print(f"{F}F is {round(C,1)}C")
# Expected output: 98.6F is 37.0C
# Out:
# Writing drill_01_temperature.py

# %% [markdown]
# Run it.

# %%
# !python drill_01_temperature.py
# Out:
# 98.6F is 37.0C

# %% [markdown]
# ### Drill 2 - Split a bill  ·  *medium*
#
# A bill of 2,847 rupees is split between 4 people. There is a 10% tip on the bill.
#
# Print:
# - the total with tip, rounded to 2 decimals
# - how much each person pays, rounded to 2 decimals
# - how many whole rupees each person pays (use integer division)

# %%
# %%writefile drill_02_bill.py
# Drill 2: splits a restaurant bill with a tip.

# YOUR CODE HERE
bill = 2847
tip = 0.1
total = bill + (bill*tip)
print(f"Total with tip: {round(total,2)}")
print(f"Each pays: {round(total/4 , 2)}")
print(f"Each pays (whole rupees): {int(total//4)}" )
# Expected:
# Total with tip: 3131.7
# Each pays: 782.93
# Each pays (whole rupees): 782
# Out:
# Overwriting drill_02_bill.py

# %% [markdown]
# Run it.

# %%
# !python drill_02_bill.py
# Out:
# Total with tip: 3131.7
# Each pays: 782.92
# Each pays (whole rupees): 782

# %% [markdown]
# ### Drill 3 - Initials and a username  ·  *hard*
#
# Given a messy full name, produce:
# - the initials, in capitals, with dots - `A.V.`
# - a username: lowercase first name + last two digits of the birth year - `asha99`
#
# Use only string methods and slicing.

# %%
# %%writefile drill_03_username.py
# Drill 3: builds initials and a username from a messy full name.

full_name = "  asha   verma  "
birth_year = 1999

# YOUR CODE HERE
clean_name = ' '.join(full_name.upper().split())
print(f"Intials: {clean_name[0]}.{clean_name[5]}.")
print(f"Username: {clean_name.lower()[0:4]}{str(birth_year)[2:]}")
# Expected:
# Initials: A.V.
# Username: asha99
# Out:
# Overwriting drill_03_username.py

# %% [markdown]
# Run it.

# %%
# !python drill_03_username.py
# Out:
# Intials: A.V.
# Username: asha99

# %% [markdown]
# ### Exercise 7 - Check your work  ·  *easy*
#
# List the files you created. All three drills should be there.

# %%
# !ls *.py
# Out:
# drill_01_temperature.py  drill_02_bill.py  drill_03_username.py  my_first.py

# %% [markdown]
# ### Exercise 8 - Write your README  ·  *medium*
#
# Every repository needs a README. It is the first and often the only thing a recruiter reads.
# Fill in the blanks below and save it.

# %%
# %%writefile README.md
# # Minor Project 1 - Python Logic Drills
#
# #Ten small programs written from scratch, with no libraries.
# #Part of the Applied AI & Analytics Lab.
#
# ## Drills
#
# | File | What it does |
# |---|---|
# | `drill_01_temperature.py` | Converts temperature from Fahrenheit to Celcius |
# | `drill_02_bill.py` | Splits bill to be paid by 4 persons |
# | `drill_03_username.py` | Creates username and initials from a messy name |
#
# ## How to run
#
# Drill 1: Temperature Converter (drill_01_temperature.py)
# What it does: Converts a temperature from Fahrenheit to Celsius and prints the result, rounded to one decimal place.
# How to run:
#
# !python drill_01_temperature.py
#
#
# ## What I learned
#
# ____
# Out:
# Writing README.md

# %% [markdown]
# ---
#
# ## Before you close this notebook
#
# 1. Create a GitHub repository called `python-logic-drills`.
# 2. Put your three `.py` files and the `README.md` in it.
# 3. Commit and push.
#
# If you have never used Git before, the four commands are:
#
# ```
# git init
# git add .
# git commit -m "MP1: first three logic drills"
# git push
# ```
#
# Drills 4 to 10 come after Session 2, once you know collections. **MP1 is due at the
# end of Session 2** - all ten, on GitHub, with the README.
#
# ---
#
# **Rule of the Lab: your GitHub is your CV. Start it today, not in month four.**
